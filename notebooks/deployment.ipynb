# %% [markdown]
# 1. Imports
#
# 2. Load processed data
#
# 3. Load FLAN-T5
#
# 4. Build AI Shopping Assistant
#
# 5. Test user questions
#
# 6. Conclusions

# %% [markdown]
# amazon-ai-shopping-assistant
# │
# ├── app/
# │   ├── api.py
# │   ├── assistant.py
# │   ├── prompt.py
# │   ├── retrieval.py
# │   ├── utils.py
# │
# ├── data/
# │   ├── category_summaries.csv
# │   ├── product_clusters.csv
# │
# ├── models/
# │
# ├── frontend/
# │
# ├── app.py
# │
# ├── requirements.txt
# │
# └── README.md
